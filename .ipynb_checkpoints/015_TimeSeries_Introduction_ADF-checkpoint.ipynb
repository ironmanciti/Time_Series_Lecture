# %% [markdown]
# # 태양 흑점 data 분석  및 ADF (Augmented Dickey–Fuller) Test

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %% [markdown]
# ## 태양 흑점 data 의 계절성, 자기 상관성 분석
#
# - 1749 년 부터 매월 말 흑점 갯수를 기록한 data
#
# - pandas asfreq - TimeSeries 를 특정한 frequency 로 표시
# ```
#     - Week	'W'	one week
#     - WeekOfMonth	'WOM'
#     - MonthEnd	'M'	calendar month end
#     - QuarterEnd	'Q'	calendar quarter end
#     - YearEnd	'A'	calendar year end
#     - Day	'D'	one absolute day
#     - Hour	'H'	one hour
#     - Minute	'T' or 'min'	one minute
#     - Second	'S'	one second
# ```

# %%
url = 'https://storage.googleapis.com/download.tensorflow.org/data/Sunspots.csv'
df = pd.read_csv(url, skiprows=0, index_col=0) # 첫 줄은 header이므로 skip 
df.head()
# Out:
#          Date  Monthly Mean Total Sunspot Number
# 0  1749-01-31                               96.7
# 1  1749-02-28                              104.3
# 2  1749-03-31                              116.7
# 3  1749-04-30                               92.8
# 4  1749-05-31                              141.7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3235 entries, 0 to 3234
# Data columns (total 2 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               3235 non-null   object
#  1   Monthly Mean Total Sunspot Number  3235 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 75.8+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3235 entries, 1749-01-31 to 2018-07-31
# Data columns (total 1 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Monthly Mean Total Sunspot Number  3235 non-null   float64
# dtypes: float64(1)
# memory usage: 50.5 KB

# %%
series = df["Monthly Mean Total Sunspot Number"].asfreq("1M")
series.head()
# Out:
# Date
# 1749-01-31     96.7
# 1749-02-28    104.3
# 1749-03-31    116.7
# 1749-04-30     92.8
# 1749-05-31    141.7
# Freq: M, Name: Monthly Mean Total Sunspot Number, dtype: float64

# %%
series.plot(figsize=(8, 4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
series["1995-01-01":].plot();

# %%
from pandas.plotting import autocorrelation_plot

autocorrelation_plot(series)
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %% [markdown]
# # Augmented Dickey Fuller test
#
# - 육안으로 time series 의 안정성 (stationary) 여부를 판단하는 것은 어려우므로 library 사용
#
#
#     - statsmodel 의 Time Series Analysis (tsa) library 사용
#     - statsmodels.tsa 는 time series analysis 에 유용한 함수들 제공
#
#
# - ADF Test
#     - https://en.wikipedia.org/wiki/Augmented_Dickey%E2%80%93Fuller_test
#
# - 반환값
#     - adf : 검정 통계량
#     - p-value : p-value 추정치
#     - critical values : 1%, 5%, 10% 수준에 해당되는 검정 통계량의 값

# %%
from statsmodels.tsa.stattools import adfuller

def adf_check(ts):
    result = adfuller(ts)
    print('ADF 검정 통계량 : {:f}'.format(result[0]))
    print('p-value: {:f} - {}'.format(result[1], 
                        'Non-stationary' if result[1] > 0.05 else 'Stationary'))
    print('Critical Values:')
    for k,v in result[4].items():
        print('\t{}: {:.3f}'.format(k, v))

# %% [markdown]
# - 태양 흑점 data의 정상성 check

# %%
X = series.values.reshape((-1, 1))

adf_check(X[:,0])
# Out:
# ADF 검정 통계량 : -10.492562
# p-value: 0.000000 - Stationary
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# - ADF Statistics < Critical Value 1% 이므로 영가설을 유의수준 1% 미만으로 reject 할 수 있다. (즉, 틀릴확률 1% 미만)
#
# - p-value < 0.05 이므로 H0 (non-stationary) 기각 -> H1(stationary) 채택

# %% [markdown]
# ## Time series 분해
#
# ### Component Type
#
# - 체계적 구성 요소 (systematic components)
#     Level : series의 평균값(moving average).
#     Trend : 연속된 time point들 간의 value change. 기울기 존재.
#     Seasonality(periodic) : 단기적 cycle을 반복하며 평균에서 벗어나는 것.
#
#
# - 비체계적 구성 요소 (non-systematic components)
#     Noise (Residual)
#
#
# - Additive model
#
#     - 𝑦(𝑡)=𝑙𝑒𝑣𝑒𝑙 + 𝑡𝑟𝑒𝑛𝑑 + 𝑠𝑒𝑎𝑠𝑜𝑛𝑎𝑙𝑖𝑡𝑦 + 𝑛𝑜𝑖𝑠𝑒 의 형태로 나누어 분석한 모델
#     - Linear model - 변화가 지속적으로 고르게 일어남
#     - linear trend, linear seasonality
#
#
# - Multiplicative model
#
#     - 𝑦(𝑡)=𝑙𝑒𝑣𝑒𝑙 ∗ 𝑡𝑟𝑒𝑛𝑑 ∗ 𝑠𝑒𝑎𝑠𝑜𝑛𝑎𝑙𝑖𝑡𝑦 ∗ 𝑛𝑜𝑖𝑠𝑒 의 형태로 나누어 분석한 모델
#     - Non-linear model - Quadratice 또는 exponential 변화가 일어나는 곳에 쓰임
#     - non-linear trend, non-linear seasonality
#     - Multiplicative model은 data에 0이 있으면 안된다. 0이 존재하면 data를 분해할 수 없기 때문이다.
#     - 주식, 경제 지표 관련 타임시리즈는 비선형에 가까움

# %% [markdown]
# 1950 - 2019 사이의 금 시세를 이용하여 Time Series 분해

# %%
df = pd.read_csv("datasets/annual_csv.csv", index_col=0, parse_dates=True)
df
# Out:
#                Price
# Date
# 1950-12-01    34.720
# 1951-12-01    34.660
# 1952-12-01    34.790
# 1953-12-01    34.850
# 1954-12-01    35.040
# ...              ...
# 2015-12-01  1068.317
# 2016-12-01  1152.165
# 2017-12-01  1265.674
# 2018-12-01  1249.887
# 2019-12-01  1480.025
#
# [70 rows x 1 columns]

# %% [markdown]
# 이동평균선 작성

# %%
WINDOW_SIZE = 12
df['rolling_mean'] = df.Price.rolling(window=WINDOW_SIZE).mean()
df['rolling_std'] = df.Price.rolling(window=WINDOW_SIZE).std()
df.plot(title='Gold Price', figsize=(12, 4))

plt.tight_layout()
plt.show()

# %% [markdown]
# ## `multiplicative model`을 사용하여 seasonality 분해
#
# - price가 multiplicative model type이라 가정하고 `multiplicative decomposition` 수행
#
# - `seasonal_decompose()`의 결과를 plot하면 4개의 sub-plot 생성
#     1. Observed - original price
#     2. Trend
#     3. Seasonality
#     4. Residual

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

results = seasonal_decompose(df.Price, model='multiplicative')

results.plot().suptitle('Multiplicative Decomposition', fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### `additive model`을 사용하여 seasonality 분해
#
# - price가 multiplicative model type이라 가정하고 `additive decomposition` 수행

# %%
results = seasonal_decompose(df.Price, model='additive')

results.plot().suptitle('Multiplicative Decomposition', fontsize=14)

plt.tight_layout()
plt.show()

# %%
adf_check(df.Price)
# Out:
# ADF 검정 통계량 : -0.367190
# p-value: 0.915434 - Non-stationary
# Critical Values:
# 	1%: -3.541
# 	5%: -2.909
# 	10%: -2.592

# %% [markdown]
# 실제 데이터의 계절성이 보이지 않으므로 seasonality를 부여하기 위해 합성 데이터를 이용하여 Time Series  분해

# %%
np.random.seed(101)

time = np.arange(500)
# white noise 생성
stationary = np.random.normal(loc=0, scale=1.0, size=len(time))
    
trend = time + stationary * 50

seasonality = 10 + np.sin(time) * 10

trend_seasonality = trend + seasonality * 10 + stationary

# %%
from datetime import datetime, timedelta
start_date = datetime(2000, 1, 1)
dates = []
for i in range(len(trend_seasonality)):
    dates.append(start_date + timedelta(i))

# %%
series_trend = pd.Series(trend_seasonality, index=dates)

# %%
results = seasonal_decompose(series_trend, model='additive')

results.plot().suptitle('Additive Decomposition', fontsize=14)

plt.tight_layout()
plt.show()
