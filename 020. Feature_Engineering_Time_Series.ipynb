# %% [markdown]
# # Time Series의 Feature Engineering

# %%
import pandas as pd
from datetime import datetime

df = pd.DataFrame()
df['date'] = [datetime(2021, 12, 1), datetime(2021, 12, 2), 
              datetime(2021, 12, 3), datetime(2021, 12, 4), datetime(2021, 12, 5)]
df['birth'] = [35, 32, 30, 31, 44]
df
# Out:
#         date  birth
# 0 2021-12-01     35
# 1 2021-12-02     32
# 2 2021-12-03     30
# 3 2021-12-04     31
# 4 2021-12-05     44

# %% [markdown]
# ## date time feature

# %%
features = df.copy()
features['year'] = df['date'].dt.year
features['month'] = df['date'].dt.month
features['day'] = df['date'].dt.day
features
# Out:
#         date  birth  year  month  day
# 0 2021-12-01     35  2021     12    1
# 1 2021-12-02     32  2021     12    2
# 2 2021-12-03     30  2021     12    3
# 3 2021-12-04     31  2021     12    4
# 4 2021-12-05     44  2021     12    5

# %% [markdown]
# ## Lag features

# %%
features['lag1'] = df['birth'].shift(1)
features['lag2'] = df['birth'].shift(3)
features
# Out:
#         date  birth  year  month  day  lag1  lag2
# 0 2021-12-01     35  2021     12    1   NaN   NaN
# 1 2021-12-02     32  2021     12    2  35.0   NaN
# 2 2021-12-03     30  2021     12    3  32.0   NaN
# 3 2021-12-04     31  2021     12    4  30.0  35.0
# 4 2021-12-05     44  2021     12    5  31.0  32.0

# %% [markdown]
# ## Window features

# %%
features['Roll_mean'] = df['birth'].rolling(window=2).mean()
features['Roll_max']  = df['birth'].rolling(window=3).max()
features
# Out:
#         date  birth  year  month  day  lag1  lag2  Roll_mean  Roll_max
# 0 2021-12-01     35  2021     12    1   NaN   NaN        NaN       NaN
# 1 2021-12-02     32  2021     12    2  35.0   NaN       33.5       NaN
# 2 2021-12-03     30  2021     12    3  32.0   NaN       31.0      35.0
# 3 2021-12-04     31  2021     12    4  30.0  35.0       30.5      32.0
# 4 2021-12-05     44  2021     12    5  31.0  32.0       37.5      44.0

# %% [markdown]
# ## Expanding features

# %%
features['Expand_max'] = df['birth'].expanding().max()
features
# Out:
#         date  birth  year  month  day  lag1  lag2  Roll_mean  Roll_max  \
# 0 2021-12-01     35  2021     12    1   NaN   NaN        NaN       NaN
# 1 2021-12-02     32  2021     12    2  35.0   NaN       33.5       NaN
# 2 2021-12-03     30  2021     12    3  32.0   NaN       31.0      35.0
# 3 2021-12-04     31  2021     12    4  30.0  35.0       30.5      32.0
# 4 2021-12-05     44  2021     12    5  31.0  32.0       37.5      44.0
#
#    Expand_max
# 0        35.0
# 1        35.0
# 2        35.0
# 3        35.0
# 4        44.0

# %% [markdown]
# ## Downsampling and Upsampling

# %%
miles_df = pd.read_csv("datasets/us-airlines-monthly-aircraft-miles-flown.csv", parse_dates=[0])
miles_df.head()
# Out:
#        Month  MilesMM
# 0 1963-01-01     6827
# 1 1963-02-01     6178
# 2 1963-03-01     7084
# 3 1963-04-01     8162
# 4 1963-05-01     8462

# %% [markdown]
# ### Downsampling
#
# - 최소 2 개의 argument 필요 : new frequency, data 상의 date column
#
# <table>
#     <th>Alias</th>
#     <th>Description</th>
#     <tr>
#     <td>B</td>
#     <td>Business day</td>
#     </tr>
#     <tr>
#     <td>D</td>
#     <td>Calendar day</td>
#     </tr>
#     <tr>
#     <td>W</td>
#     <td>Weekly</td>
#     </tr>
#     <tr>
#     <td>M</td>
#     <td>Monthly</td>
#     </tr>
#     <tr>
#     <td>Q</td>
#     <td>Quarter end</td>
#     </tr>
#     <tr>
#     <td>A</td>
#     <td>Year end</td>
#     </tr>
#     <tr>
#     <td>BA</td>
#     <td>Business Year end</td>
#     </tr>
#     <tr>
#     <td>H</td>
#     <td>Hourly frequency</td>
#     </tr>
#     <tr>
#     <td>S</td>
#     <td>Second frequency</td>
#     </tr>
# </table>

# %%
quarterly_miles_df = miles_df.resample('Q', on='Month').mean()
quarterly_miles_df.head()
# Out:
#                  MilesMM
# Month
# 1963-03-31   6696.333333
# 1963-06-30   8756.000000
# 1963-09-30  10392.333333
# 1963-12-31   7356.333333
# 1964-03-31   7287.666667

# %%
yearly_miles_df = miles_df.resample('A', on='Month').sum()
yearly_miles_df.head()
# Out:
#             MilesMM
# Month
# 1963-12-31    99603
# 1964-12-31   106192
# 1965-12-31   115431
# 1966-12-31   119154
# 1967-12-31   126515

# %% [markdown]
# ### `first() / last()` method

# %%
i = pd.date_range('2018-04-09', periods=4, freq='2D')
ts = pd.DataFrame({'A': [1, 2, 3, 4]}, index=i)
ts
# Out:
#             A
# 2018-04-09  1
# 2018-04-11  2
# 2018-04-13  3
# 2018-04-15  4

# %%
#last 3 observation이 아니라 3D이므로 2개 return
ts.last('3D')
# Out:
#             A
# 2018-04-13  3
# 2018-04-15  4

# %% [markdown]
# ### Upsampling
# - increase frequency

# %%
upsampled_miles_df = miles_df.resample('D', on='Month').mean()
upsampled_miles_df.head(35)
# Out:
#             MilesMM
# Month
# 1963-01-01   6827.0
# 1963-01-02      NaN
# 1963-01-03      NaN
# 1963-01-04      NaN
# 1963-01-05      NaN
# 1963-01-06      NaN
# 1963-01-07      NaN
# 1963-01-08      NaN
# 1963-01-09      NaN
# 1963-01-10      NaN
# 1963-01-11      NaN
# 1963-01-12      NaN
# 1963-01-13      NaN
# 1963-01-14      NaN
# 1963-01-15      NaN
# 1963-01-16      NaN
# 1963-01-17      NaN
# 1963-01-18      NaN
# 1963-01-19      NaN
# 1963-01-20      NaN
# 1963-01-21      NaN
# 1963-01-22      NaN
# 1963-01-23      NaN
# 1963-01-24      NaN
# 1963-01-25      NaN
# 1963-01-26      NaN
# 1963-01-27      NaN
# 1963-01-28      NaN
# 1963-01-29      NaN
# 1963-01-30      NaN
# 1963-01-31      NaN
# 1963-02-01   6178.0
# 1963-02-02      NaN
# 1963-02-03      NaN
# 1963-02-04      NaN

# %%
interpolated_miles_df = upsampled_miles_df.interpolate(method='linear')
interpolated_miles_df.head(35)
# Out:
#                 MilesMM
# Month
# 1963-01-01  6827.000000
# 1963-01-02  6806.064516
# 1963-01-03  6785.129032
# 1963-01-04  6764.193548
# 1963-01-05  6743.258065
# 1963-01-06  6722.322581
# 1963-01-07  6701.387097
# 1963-01-08  6680.451613
# 1963-01-09  6659.516129
# 1963-01-10  6638.580645
# 1963-01-11  6617.645161
# 1963-01-12  6596.709677
# 1963-01-13  6575.774194
# 1963-01-14  6554.838710
# 1963-01-15  6533.903226
# 1963-01-16  6512.967742
# 1963-01-17  6492.032258
# 1963-01-18  6471.096774
# 1963-01-19  6450.161290
# 1963-01-20  6429.225806
# 1963-01-21  6408.290323
# 1963-01-22  6387.354839
# 1963-01-23  6366.419355
# 1963-01-24  6345.483871
# 1963-01-25  6324.548387
# 1963-01-26  6303.612903
# 1963-01-27  6282.677419
# 1963-01-28  6261.741935
# 1963-01-29  6240.806452
# 1963-01-30  6219.870968
# 1963-01-31  6198.935484
# 1963-02-01  6178.000000
# 1963-02-02  6210.357143
# 1963-02-03  6242.714286
# 1963-02-04  6275.071429

# %%
interpolated_miles_df.diff(-1)
# Out:
#               MilesMM
# Month
# 1963-01-01  20.935484
# 1963-01-02  20.935484
# 1963-01-03  20.935484
# 1963-01-04  20.935484
# 1963-01-05  20.935484
# ...               ...
# 1970-11-27 -39.233333
# 1970-11-28 -39.233333
# 1970-11-29 -39.233333
# 1970-11-30 -39.233333
# 1970-12-01        NaN
#
# [2892 rows x 1 columns]

# %%
interpolated_miles_df.plot()
# Out:
# <AxesSubplot:xlabel='Month'>
